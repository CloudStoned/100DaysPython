# %% [markdown]
# # Introduction
#
# In this notebook, we will do a comprehensive analysis of the Android app market by comparing thousands of apps in the Google Play store.

# %% [markdown]
# # About the Dataset of Google Play Store Apps & Reviews

# %% [markdown]
# **Data Source:** <br>
# App and review data was scraped from the Google Play Store by Lavanya Gupta in 2018. Original files listed [here](
# https://www.kaggle.com/lava18/google-play-store-apps).

# %% [markdown]
# # Import Statements

# %%
import pandas as pd
import plotly.express as px

# %% [markdown]
# # Notebook Presentation

# %%
# Show numeric output in decimal format e.g., 2.15
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# # Read the Dataset

# %%
df_apps = pd.read_csv('apps.csv')

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# **Challenge**: How many rows and columns does `df_apps` have? What are the column names? Look at a random sample of 5 different rows with [.sample()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sample.html).

# %%
df_apps.shape
# Out:
# (10841, 12)

# %%
df_apps.head()
# Out:
#                                             App         Category  Rating  \
# 0                       Ak Parti Yardım Toplama           SOCIAL     NaN
# 1                    Ain Arabic Kids Alif Ba ta           FAMILY     NaN
# 2  Popsicle Launcher for Android P 9.0 launcher  PERSONALIZATION     NaN
# 3                     Command & Conquer: Rivals           FAMILY     NaN
# 4                                    CX Network         BUSINESS     NaN
#
#    Reviews  Size_MBs Installs  Type   Price Content_Rating           Genres  \
# 0        0      8.70        0  Paid  $13.99           Teen           Social
# 1        0     33.00        0  Paid   $2.99       Everyone        Education
# 2        0      5.50        0  Paid   $1.49       Everyone  Personalization
# 3        0     19.00        0   NaN       0   Everyone 10+         Strategy
# 4        0     10.00        0  Free       0       Everyone         Business
#
#      Last_Updated         Android_Ver
# 0   July 28, 2017          4.1 and up
# 1  April 15, 2016          3.0 and up
# 2   July 11, 2018          4.2 and up
# 3   June 28, 2018  Varies with device
# 4  August 6, 2018          4.1 and up

# %%
df_apps.sample(5)
# Out:
#                                                     App          Category  \
# 8770                       KAYAK Flights, Hotels & Cars  TRAVEL_AND_LOCAL
# 9900                     Rento - Dice Board Game Online              GAME
# 2646                             SMS Sender - sluzba.cz     COMMUNICATION
# 5410  Pixel art pro-Sand box,paint by number,number ...            FAMILY
# 911                                                  DS            FAMILY
#
#       Rating  Reviews  Size_MBs    Installs  Type Price Content_Rating  \
# 8770    4.50   216388     19.00  10,000,000  Free     0       Everyone
# 9900    4.30   205830     63.00  10,000,000  Free     0       Everyone
# 2646     NaN       12      0.07       1,000  Free     0       Everyone
# 5410    4.50     2442     13.00     100,000  Free     0       Everyone
# 911     4.90       15     23.00         100  Free     0       Everyone
#
#                   Genres      Last_Updated         Android_Ver
# 8770      Travel & Local     July 31, 2018  Varies with device
# 9900               Board     June 20, 2018          4.1 and up
# 2646       Communication      June 1, 2012          2.0 and up
# 5410  Casual;Brain Games      July 6, 2018        4.0.3 and up
# 911               Casual  January 19, 2016          2.3 and up

# %% [markdown]
# ### Drop Unused Columns
#
# **Challenge**: Remove the columns called `Last_Updated` and `Android_Version` from the DataFrame. We will not use these columns.

# %%
df_apps.drop(['Last_Updated', 'Android_Ver'], axis=1, inplace=True)
df_apps.head()
# Out:
#                                             App         Category  Rating  \
# 0                       Ak Parti Yardım Toplama           SOCIAL     NaN
# 1                    Ain Arabic Kids Alif Ba ta           FAMILY     NaN
# 2  Popsicle Launcher for Android P 9.0 launcher  PERSONALIZATION     NaN
# 3                     Command & Conquer: Rivals           FAMILY     NaN
# 4                                    CX Network         BUSINESS     NaN
#
#    Reviews  Size_MBs Installs  Type   Price Content_Rating           Genres
# 0        0      8.70        0  Paid  $13.99           Teen           Social
# 1        0     33.00        0  Paid   $2.99       Everyone        Education
# 2        0      5.50        0  Paid   $1.49       Everyone  Personalization
# 3        0     19.00        0   NaN       0   Everyone 10+         Strategy
# 4        0     10.00        0  Free       0       Everyone         Business

# %% [markdown]
# ### Find and Remove NaN values in Ratings
#
# **Challenge**: How may rows have a NaN value (not-a-number) in the Ratings column? Create DataFrame called `df_apps_clean` that does not include these rows.

# %%
nan_rows = df_apps[df_apps.Rating.isna()]
print(nan_rows.shape)
nan_rows.head()
# Out:
# (1474, 10)
#                                             App         Category  Rating  \
# 0                       Ak Parti Yardım Toplama           SOCIAL     NaN
# 1                    Ain Arabic Kids Alif Ba ta           FAMILY     NaN
# 2  Popsicle Launcher for Android P 9.0 launcher  PERSONALIZATION     NaN
# 3                     Command & Conquer: Rivals           FAMILY     NaN
# 4                                    CX Network         BUSINESS     NaN
#
#    Reviews  Size_MBs Installs  Type   Price Content_Rating           Genres
# 0        0      8.70        0  Paid  $13.99           Teen           Social
# 1        0     33.00        0  Paid   $2.99       Everyone        Education
# 2        0      5.50        0  Paid   $1.49       Everyone  Personalization
# 3        0     19.00        0   NaN       0   Everyone 10+         Strategy
# 4        0     10.00        0  Free       0       Everyone         Business

# %%
df_app_clean = df_apps.dropna()
df_app_clean.shape
# Out:
# (9367, 10)

# %% [markdown]
# ### Find and Remove Duplicates
#
# **Challenge**: Are there any duplicates in data? Check for duplicates using the [.duplicated()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.duplicated.html) function. How many entries can you find for the "Instagram" app? Use [.drop_duplicates()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop_duplicates.html) to remove any duplicates from `df_apps_clean`.

# %%
duplicated_rows = df_app_clean[df_app_clean.duplicated()]
print(duplicated_rows.shape)
duplicated_rows.head()
# Out:
# (476, 10)
#                                              App Category  Rating  Reviews  \
# 946                       420 BZ Budeze Delivery  MEDICAL    5.00        2
# 1133                                 MouseMingle   DATING    2.70        3
# 1196  Cardiac diagnosis (heart rate, arrhythmia)  MEDICAL    4.40        8
# 1231                                Sway Medical  MEDICAL    5.00        3
# 1247              Chat Kids - Chat Room For Kids   DATING    4.70        6
#
#       Size_MBs Installs  Type   Price Content_Rating   Genres
# 946      11.00      100  Free       0     Mature 17+  Medical
# 1133      3.90      100  Free       0     Mature 17+   Dating
# 1196      6.50      100  Paid  $12.99       Everyone  Medical
# 1231     22.00      100  Free       0       Everyone  Medical
# 1247      4.90      100  Free       0     Mature 17+   Dating

# %%
df_app_clean[df_app_clean.App == 'Instagram']
# Out:
#              App Category  Rating   Reviews  Size_MBs       Installs  Type  \
# 10806  Instagram   SOCIAL    4.50  66577313      5.30  1,000,000,000  Free
# 10808  Instagram   SOCIAL    4.50  66577446      5.30  1,000,000,000  Free
# 10809  Instagram   SOCIAL    4.50  66577313      5.30  1,000,000,000  Free
# 10810  Instagram   SOCIAL    4.50  66509917      5.30  1,000,000,000  Free
#
#       Price Content_Rating  Genres
# 10806     0           Teen  Social
# 10808     0           Teen  Social
# 10809     0           Teen  Social
# 10810     0           Teen  Social

# %%
df_app_clean = df_app_clean.drop_duplicates()
df_app_clean[df_app_clean.App == 'Instagram']
# Out:
#              App Category  Rating   Reviews  Size_MBs       Installs  Type  \
# 10806  Instagram   SOCIAL    4.50  66577313      5.30  1,000,000,000  Free
# 10808  Instagram   SOCIAL    4.50  66577446      5.30  1,000,000,000  Free
# 10810  Instagram   SOCIAL    4.50  66509917      5.30  1,000,000,000  Free
#
#       Price Content_Rating  Genres
# 10806     0           Teen  Social
# 10808     0           Teen  Social
# 10810     0           Teen  Social

# %%
# need to specify the subset for identifying duplicates
df_app_clean = df_app_clean.drop_duplicates(subset=['App', 'Type', 'Price'])
df_app_clean[df_app_clean.App == 'Instagram']
# Out:
#              App Category  Rating   Reviews  Size_MBs       Installs  Type  \
# 10806  Instagram   SOCIAL    4.50  66577313      5.30  1,000,000,000  Free
#
#       Price Content_Rating  Genres
# 10806     0           Teen  Social

# %%
df_app_clean.shape
# Out:
# (8199, 10)

# %% [markdown]
# # Find Highest Rated Apps
#
# **Challenge**: Identify which apps are the highest rated. What problem might you encounter if you rely exclusively on ratings alone to determine the quality of an app?

# %%
df_app_clean.sort_values('Rating', ascending=False).head()
# Out:
#                                            App     Category  Rating  Reviews  \
# 21                         KBA-EZ Health Guide      MEDICAL    5.00        4
# 1751                     Spine- The dating app       DATING    5.00        5
# 1761             Selfie With Champion AJ Style  PHOTOGRAPHY    5.00        2
# 1763                     Ag Valley Cooperative     BUSINESS    5.00        6
# 1769  Yazdani Cd Center EllahAbad Official App       FAMILY    5.00        8
#
#       Size_MBs Installs  Type Price Content_Rating         Genres
# 21       25.00        1  Free     0       Everyone        Medical
# 1751      9.30      500  Free     0           Teen         Dating
# 1761      7.50      500  Free     0       Everyone    Photography
# 1763     74.00      500  Free     0       Everyone       Business
# 1769      3.80      500  Free     0       Everyone  Entertainment

# %% [markdown]
# # Find 5 Largest Apps in terms of Size (MBs)
#
# **Challenge**: What's the size in megabytes (MB) of the largest Android apps in the Google Play Store. Based on the data, do you think there could be limit in place or can developers make apps as large as they please?

# %%
df_app_clean.sort_values('Size_MBs', ascending=False).head()
# Out:
#                                      App Category  Rating  Reviews  Size_MBs  \
# 8719          Draft Simulator for FUT 18   SPORTS    4.60   162933    100.00
# 8718   Mini Golf King - Multiplayer Game     GAME    4.50   531458    100.00
# 10295                    SimCity BuildIt   FAMILY    4.50  4218587    100.00
# 9945                     Ultimate Tennis   SPORTS    4.30   183004    100.00
# 9944        Gangster Town: Vice District   FAMILY    4.30    65146    100.00
#
#          Installs  Type Price Content_Rating      Genres
# 8719    5,000,000  Free     0       Everyone      Sports
# 8718    5,000,000  Free     0       Everyone      Sports
# 10295  50,000,000  Free     0   Everyone 10+  Simulation
# 9945   10,000,000  Free     0       Everyone      Sports
# 9944   10,000,000  Free     0     Mature 17+  Simulation

# %% [markdown]
# # Find the 5 App with Most Reviews
#
# **Challenge**: Which apps have the highest number of reviews? Are there any paid apps among the top 50?

# %%
df_app_clean.sort_values('Reviews', ascending=False).head()
# Out:
#                                             App       Category  Rating  \
# 10805                                  Facebook         SOCIAL    4.10
# 10785                        WhatsApp Messenger  COMMUNICATION    4.40
# 10806                                 Instagram         SOCIAL    4.50
# 10784  Messenger – Text and Video Chat for Free  COMMUNICATION    4.00
# 10650                            Clash of Clans           GAME    4.60
#
#         Reviews  Size_MBs       Installs  Type Price Content_Rating  \
# 10805  78158306      5.30  1,000,000,000  Free     0           Teen
# 10785  69119316      3.50  1,000,000,000  Free     0       Everyone
# 10806  66577313      5.30  1,000,000,000  Free     0           Teen
# 10784  56642847      3.50  1,000,000,000  Free     0       Everyone
# 10650  44891723     98.00    100,000,000  Free     0   Everyone 10+
#
#               Genres
# 10805         Social
# 10785  Communication
# 10806         Social
# 10784  Communication
# 10650       Strategy

# %% [markdown]
# # Plotly Pie and Donut Charts - Visualise Categorical Data: Content Ratings

# %%
ratings = df_app_clean.Content_Rating.value_counts()
ratings
# Out:
# Content_Rating
# Everyone           6621
# Teen                912
# Mature 17+          357
# Everyone 10+        305
# Adults only 18+       3
# Unrated               1
# Name: count, dtype: int64

# %%
fig = px.pie(labels=ratings.index, values=ratings.values)
fig.show()

# %%
fig = px.pie(labels=ratings.index, values=ratings.values,
             title='Content Rating',
             names = ratings.index)
fig.update_traces(textposition='outside', textinfo = 'percent+label')

fig.show()

# %%
fig = px.pie(labels=ratings.index,
values=ratings.values,
title="Content Rating",
names=ratings.index,
hole=0.6,
)
fig.update_traces(textposition='inside', textfont_size=15, textinfo='percent')
 
fig.show()

# %% [markdown]
# # Numeric Type Conversion: Examine the Number of Installs
#
# **Challenge**: How many apps had over 1 billion (that's right - BILLION) installations? How many apps just had a single install?
#
# Check the datatype of the Installs column.
#
# Count the number of apps at each level of installations.
#
# Convert the number of installations (the Installs column) to a numeric data type. Hint: this is a 2-step process. You'll have make sure you remove non-numeric characters first.

# %%
df_app_clean.Installs.describe()
# Out:
# count          8199
# unique           19
# top       1,000,000
# freq           1417
# Name: Installs, dtype: object

# %%
df_app_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8199 entries, 21 to 10835
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             8199 non-null   object
#  1   Category        8199 non-null   object
#  2   Rating          8199 non-null   float64
#  3   Reviews         8199 non-null   int64
#  4   Size_MBs        8199 non-null   float64
#  5   Installs        8199 non-null   object
#  6   Type            8199 non-null   object
#  7   Price           8199 non-null   object
#  8   Content_Rating  8199 non-null   object
#  9   Genres          8199 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 704.6+ KB

# %%
df_app_clean[['App', 'Installs']].groupby('Installs').count()
# Out:
#                 App
# Installs
# 1                 3
# 1,000           698
# 1,000,000      1417
# 1,000,000,000    20
# 10               69
# 10,000          988
# 10,000,000      933
# 100             303
# 100,000        1096
# 100,000,000     189
# 5                 9
# 5,000           425
# 5,000,000       607
# 50               56
# 50,000          457
# 50,000,000      202
# 500             199
# 500,000         504
# 500,000,000      24

# %%
df_app_clean.Installs = df_app_clean.Installs.astype(str).str.replace(',', "")
df_app_clean.Installs = pd.to_numeric(df_app_clean.Installs)
df_app_clean[['App', 'Installs']].groupby('Installs').count()
# Out:
#              App
# Installs
# 1              3
# 5              9
# 10            69
# 50            56
# 100          303
# 500          199
# 1000         698
# 5000         425
# 10000        988
# 50000        457
# 100000      1096
# 500000       504
# 1000000     1417
# 5000000      607
# 10000000     933
# 50000000     202
# 100000000    189
# 500000000     24
# 1000000000    20

# %% [markdown]
# # Find the Most Expensive Apps, Filter out the Junk, and Calculate a (ballpark) Sales Revenue Estimate
#
# Let's examine the Price column more closely.
#
# **Challenge**: Convert the price column to numeric data. Then investigate the top 20 most expensive apps in the dataset.
#
# Remove all apps that cost more than $250 from the `df_apps_clean` DataFrame.
#
# Add a column called 'Revenue_Estimate' to the DataFrame. This column should hold the price of the app times the number of installs. What are the top 10 highest grossing paid apps according to this estimate? Out of the top 10 highest grossing paid apps, how many are games?

# %%
df_app_clean.Price.describe()
# Out:
# count           8,199.00
# mean        9,169,323.86
# std        58,249,330.53
# min                 1.00
# 25%            10,000.00
# 50%           100,000.00
# 75%         1,000,000.00
# max     1,000,000,000.00
# Name: Price, dtype: float64

# %%
df_app_clean.Price = df_app_clean.Price.astype(str).str.replace('$', "")
df_app_clean.Price = pd.to_numeric(df_app_clean.Price)
 
df_app_clean.sort_values('Price', ascending=False).head(20)
# Out:
#                                             App             Category  Rating  \
# 10784  Messenger – Text and Video Chat for Free        COMMUNICATION    4.00
# 10822                                    Google                TOOLS    4.40
# 10803                         Google Play Games        ENTERTAINMENT    4.30
# 10792             Skype - free IM & video calls        COMMUNICATION    4.10
# 10788                                  Hangouts        COMMUNICATION    4.00
# 10787                                     Gmail        COMMUNICATION    4.30
# 10786              Google Chrome: Fast & Secure        COMMUNICATION    4.30
# 10828                                   YouTube        VIDEO_PLAYERS    4.30
# 10783                         Google Play Books  BOOKS_AND_REFERENCE    3.90
# 10785                        WhatsApp Messenger        COMMUNICATION    4.40
# 10824                              Google Drive         PRODUCTIVITY    4.40
# 10831                               Google News   NEWS_AND_MAGAZINES    3.90
# 10818                        Google Street View     TRAVEL_AND_LOCAL    4.20
# 10817                 Maps - Navigate & Explore     TRAVEL_AND_LOCAL    4.30
# 10813                             Google Photos          PHOTOGRAPHY    4.50
# 10807                                   Google+               SOCIAL    4.20
# 10806                                 Instagram               SOCIAL    4.50
# 10805                                  Facebook               SOCIAL    4.10
# 10835                            Subway Surfers                 GAME    4.50
# 10829                   Google Play Movies & TV        VIDEO_PLAYERS    3.70
#
#         Reviews  Size_MBs    Installs  Type       Price Content_Rating  \
# 10784  56642847      3.50  1000000000  Free  1000000000       Everyone
# 10822   8033493      3.40  1000000000  Free  1000000000       Everyone
# 10803   7165362      9.35  1000000000  Free  1000000000           Teen
# 10792  10484169      3.50  1000000000  Free  1000000000       Everyone
# 10788   3419249      3.50  1000000000  Free  1000000000       Everyone
# 10787   4604324      3.50  1000000000  Free  1000000000       Everyone
# 10786   9642995      3.50  1000000000  Free  1000000000       Everyone
# 10828  25655305      4.65  1000000000  Free  1000000000           Teen
# 10783   1433233      5.70  1000000000  Free  1000000000           Teen
# 10785  69119316      3.50  1000000000  Free  1000000000       Everyone
# 10824   2731171      4.00  1000000000  Free  1000000000       Everyone
# 10831    877635     13.00  1000000000  Free  1000000000           Teen
# 10818   2129689     12.00  1000000000  Free  1000000000       Everyone
# 10817   9235155     12.00  1000000000  Free  1000000000       Everyone
# 10813  10858556      6.90  1000000000  Free  1000000000       Everyone
# 10807   4831125      5.30  1000000000  Free  1000000000           Teen
# 10806  66577313      5.30  1000000000  Free  1000000000           Teen
# 10805  78158306      5.30  1000000000  Free  1000000000           Teen
# 10835  27722264     76.00  1000000000  Free  1000000000   Everyone 10+
# 10829    906384      4.65  1000000000  Free  1000000000           Teen
#
#                         Genres
# 10784            Communication
# 10822                    Tools
# 10803            Entertainment
# 10792            Communication
# 10788            Communication
# 10787            Communication
# 10786            Communication
# 10828  Video Players & Editors
# 10783        Books & Reference
# 10785            Communication
# 10824             Productivity
# 10831         News & Magazines
# 10818           Travel & Local
# 10817           Travel & Local
# 10813              Photography
# 10807                   Social
# 10806                   Social
# 10805                   Social
# 10835                   Arcade
# 10829  Video Players & Editors

# %% [markdown]
# ### The most expensive apps sub $250

# %%
df_app_clean = df_app_clean[df_app_clean['Price'] < 250]
df_app_clean.sort_values('Price', ascending=False).head(5)
# Out:
#                                           App         Category  Rating  \
# 1473                Ad Removal: thereisonlywe     PRODUCTIVITY    3.40
# 1472                                 FO Bixby  PERSONALIZATION    5.00
# 1471                          Pint - FN Theme  PERSONALIZATION    2.50
# 1470                    RETRO Shocked DW-6000  PERSONALIZATION    5.00
# 1428  Theme Android P Black design for LG V30  PERSONALIZATION    4.40
#
#       Reviews  Size_MBs  Installs  Type  Price Content_Rating           Genres
# 1473       16      0.29       100  Paid    100       Everyone     Productivity
# 1472        5      0.84       100  Paid    100       Everyone  Personalization
# 1471        6      0.23       100  Free    100       Everyone  Personalization
# 1470       13      0.49       100  Paid    100       Everyone  Personalization
# 1428        8      6.20       100  Paid    100       Everyone  Personalization

# %% [markdown]
# ### Highest Grossing Paid Apps (ballpark estimate)

# %%
df_app_clean['Revenue_Estimate'] = df_app_clean.Installs.mul(df_app_clean.Price)
df_app_clean.sort_values('Revenue_Estimate', ascending=False)[:10]
# Out:
#                                                  App            Category  \
# 1473                       Ad Removal: thereisonlywe        PRODUCTIVITY
# 1472                                        FO Bixby     PERSONALIZATION
# 1471                                 Pint - FN Theme     PERSONALIZATION
# 1470                           RETRO Shocked DW-6000     PERSONALIZATION
# 1428         Theme Android P Black design for LG V30     PERSONALIZATION
# 1426                                 BU Bison Nation              SPORTS
# 1425                                       DN Reader  NEWS_AND_MAGAZINES
# 1423                       HON. B.J. ACS COLLEGE ALE              FAMILY
# 1417                                       FH School              FAMILY
# 1416  Ek Kahani Aisi Bhi Season 3 - The Horror Story              FAMILY
#
#       Rating  Reviews  Size_MBs  Installs  Type  Price Content_Rating  \
# 1473    3.40       16      0.29       100  Paid    100       Everyone
# 1472    5.00        5      0.84       100  Paid    100       Everyone
# 1471    2.50        6      0.23       100  Free    100       Everyone
# 1470    5.00       13      0.49       100  Paid    100       Everyone
# 1428    4.40        8      6.20       100  Paid    100       Everyone
# 1426    3.50        4     40.00       100  Free    100       Everyone
# 1425    4.60       18      1.80       100  Free    100       Everyone
# 1423    5.00        3      1.80       100  Free    100     Mature 17+
# 1417    5.00        4      5.80       100  Free    100       Everyone
# 1416    3.00        1      5.80       100  Free    100           Teen
#
#                 Genres  Revenue_Estimate
# 1473      Productivity             10000
# 1472   Personalization             10000
# 1471   Personalization             10000
# 1470   Personalization             10000
# 1428   Personalization             10000
# 1426            Sports             10000
# 1425  News & Magazines             10000
# 1423         Education             10000
# 1417         Education             10000
# 1416     Entertainment             10000

# %% [markdown]
# # Plotly Bar Charts & Scatter Plots: Analysing App Categories

# %%
df_app_clean.Category.nunique()
# Out:
# 28

# %%
top10_category = df_app_clean.Category.value_counts()[:10]
top10_category
# Out:
# Category
# FAMILY                90
# MEDICAL               38
# BUSINESS              35
# TOOLS                 32
# PERSONALIZATION       30
# GAME                  28
# LIFESTYLE             24
# PRODUCTIVITY          20
# COMMUNICATION         19
# HEALTH_AND_FITNESS    16
# Name: count, dtype: int64

# %% [markdown]
# ### Vertical Bar Chart - Highest Competition (Number of Apps)

# %%
bar = px.bar(x = top10_category.index,
             y = top10_category.values)
bar.show()

# %% [markdown]
# ### Horizontal Bar Chart - Most Popular Categories (Highest Downloads)

# %%
category_installs = df_app_clean.groupby('Category').agg({'Installs': pd.Series.sum})
category_installs.sort_values('Installs', ascending=True, inplace=True)

# %%
h_bar = px.bar(x = category_installs.Installs,
               y = category_installs.index,
               orientation='h',
               title='Category Popularity')

h_bar.update_layout(xaxis_title='Number of Downloads',
                    yaxis_title='Category')

h_bar.show()

# %% [markdown]
# ### Category Concentration - Downloads vs. Competition
#
# **Challenge**:
# * First, create a DataFrame that has the number of apps in one column and the number of installs in another:
#
# <img src=https://imgur.com/uQRSlXi.png width="350">
#
# * Then use the [plotly express examples from the documentation](https://plotly.com/python/line-and-scatter/) alongside the [.scatter() API reference](https://plotly.com/python-api-reference/generated/plotly.express.scatter.html)to create scatter plot that looks like this.
#
# <img src=https://imgur.com/cHsqh6a.png>
#
# *Hint*: Use the size, hover_name and color parameters in .scatter(). To scale the yaxis, call .update_layout() and specify that the yaxis should be on a log-scale like so: yaxis=dict(type='log')

# %%
cat_number = df_app_clean.groupby('Category').agg({'App': pd.Series.count})

cat_merged_df = pd.merge(cat_number, category_installs, on='Category', how='inner')
print(f'The dimensions of the DF are: {cat_merged_df.shape}')
cat_merged_df.sort_values('Installs',ascending=False)
# Out:
# The dimensions of the DF are: (28, 2)
#                      App  Installs
# Category
# FAMILY                90      6590
# MEDICAL               38      2676
# BUSINESS              35      2620
# TOOLS                 32      2500
# PERSONALIZATION       30      2430
# LIFESTYLE             24      2120
# GAME                  28      1717
# PRODUCTIVITY          20      1680
# COMMUNICATION         19      1530
# HEALTH_AND_FITNESS    16      1220
# NEWS_AND_MAGAZINES    12      1150
# SOCIAL                13       975
# SPORTS                12       965
# DATING                10       910
# FINANCE               11       900
# PHOTOGRAPHY            9       630
# MAPS_AND_NAVIGATION    7       560
# SHOPPING               9       540
# EVENTS                 5       410
# AUTO_AND_VEHICLES      3       300
# TRAVEL_AND_LOCAL       3       300
# FOOD_AND_DRINK         3       250
# VIDEO_PLAYERS          2       200
# BEAUTY                 2       200
# BOOKS_AND_REFERENCE    3       155
# PARENTING              2       110
# COMICS                 1       100
# ART_AND_DESIGN         1       100

# %%
scatter = px.scatter(cat_merged_df,
                     x='App',
                     y='Installs',
                     title='Category Concentration',
                     size='App',
                     hover_name=cat_merged_df.index,
                     color='Installs')

scatter.update_layout(xaxis_title='Number of Apps (Lower=More Concentrated)',
                      yaxis_title='Installs',
                      yaxis=dict(type='log'))

scatter.show()

# %% [markdown]
# # Extracting Nested Data from a Column
#
# **Challenge**: How many different types of genres are there? Can an app belong to more than one genre? Check what happens when you use .value_counts() on a column with nested values? See if you can work around this problem by using the .split() function and the DataFrame's [.stack() method](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.stack.html).

# %%
# Number of Genres
len(df_app_clean.Genres.unique())
# Out:
# 42

# %%
# Problem: Have multiple categories separeted by ;
df_app_clean.Genres.value_counts().sort_values(ascending=True)[:5]
# Out:
# Genres
# Trivia               1
# Art & Design         1
# Casino               1
# Comics               1
# Board;Brain Games    1
# Name: count, dtype: int64

# %%
# Split the strings on the semi-colon and then .stack them
stack = df_app_clean.Genres.str.split(';', expand=True).stack()
print(f'We now have a single column with shape: {stack.shape}')
num_genres = stack.value_counts()
print(f'Number of genres: {len(num_genres)}')
# Out:
# We now have a single column with shape: (444,)
# Number of genres: 42

# %% [markdown]
# # Colour Scales in Plotly Charts - Competition in Genres

# %% [markdown]
# **Challenge**: Can you create this chart with the Series containing the genre data?
#
# <img src=https://imgur.com/DbcoQli.png width=400>
#
# Try experimenting with the built in colour scales in Plotly. You can find a full list [here](https://plotly.com/python/builtin-colorscales/).
#
# * Find a way to set the colour scale using the color_continuous_scale parameter.
# * Find a way to make the color axis disappear by using coloraxis_showscale.

# %%
bar = px.bar(x = num_genres.index[:15], # index = category name
             y = num_genres.values[:15], # count
             title='Top Genres',
             hover_name=num_genres.index[:15],
             color=num_genres.values[:15],
             color_continuous_scale='Agsunset')
 
bar.update_layout(xaxis_title='Genre',
yaxis_title='Number of Apps',
coloraxis_showscale=False)
 
bar.show()

# %% [markdown]
# # Grouped Bar Charts: Free vs. Paid Apps per Category

# %%
df_free_vs_paid = df_app_clean.groupby(["Category", "Type"], as_index=False).agg({'App': pd.Series.count})
df_free_vs_paid.head()
# Out:
#               Category  Type  App
# 0       ART_AND_DESIGN  Free    1
# 1    AUTO_AND_VEHICLES  Free    3
# 2               BEAUTY  Free    2
# 3  BOOKS_AND_REFERENCE  Free    1
# 4  BOOKS_AND_REFERENCE  Paid    2

# %% [markdown]
# **Challenge**: Use the plotly express bar [chart examples](https://plotly.com/python/bar-charts/#bar-chart-with-sorted-or-ordered-categories) and the [.bar() API reference](https://plotly.com/python-api-reference/generated/plotly.express.bar.html#plotly.express.bar) to create this bar chart:
#
# <img src=https://imgur.com/LE0XCxA.png>
#
# You'll want to use the `df_free_vs_paid` DataFrame that you created above that has the total number of free and paid apps per category.
#
# See if you can figure out how to get the look above by changing the `categoryorder` to 'total descending' as outlined in the documentation here [here](https://plotly.com/python/categorical-axes/#automatically-sorting-categories-by-name-or-total-value).

# %%
g_bar = px.bar(df_free_vs_paid,
               x='Category',
               y='App',
               title='Free vs Paid Apps by Category',
               color='Type',
               barmode='group')
 
g_bar.update_layout(xaxis_title='Category',
                    yaxis_title='Number of Apps',
                    xaxis={'categoryorder':'total descending'},
                    yaxis=dict(type='log'))
 
g_bar.show()

# %% [markdown]
# # Plotly Box Plots: Lost Downloads for Paid Apps
#
# **Challenge**: Create a box plot that shows the number of Installs for free versus paid apps. How does the median number of installations compare? Is the difference large or small?
#
# Use the [Box Plots Guide](https://plotly.com/python/box-plots/) and the [.box API reference](https://plotly.com/python-api-reference/generated/plotly.express.box.html) to create the following chart.
#
# <img src=https://imgur.com/uVsECT3.png>

# %%
box = px.box(df_app_clean,
             y='Installs',
             x='Type',
             color='Type',
             notched=True,
             points='all',
             title='How Many Downloads are Paid Apps Giving Up?')
 
box.update_layout(yaxis=dict(type='log'))
 
box.show()

# %% [markdown]
# # Plotly Box Plots: Revenue by App Category
#
# **Challenge**: See if you can generate the chart below:
#
# <img src=https://imgur.com/v4CiNqX.png>
#
# Looking at the hover text, how much does the median app earn in the Tools category? If developing an Android app costs $30,000 or thereabouts, does the average photography app recoup its development costs?
#
# Hint: I've used 'min ascending' to sort the categories.

# %%
df_paid_apps = df_app_clean[df_app_clean['Type'] == 'Paid']
box = px.box(df_paid_apps, 
             x='Category', 
             y='Revenue_Estimate',
             title='How Much Can Paid Apps Earn?')
 
box.update_layout(xaxis_title='Category',
                  yaxis_title='Paid App Ballpark Revenue',
                  xaxis={'categoryorder':'min ascending'},
                  yaxis=dict(type='log'))
 
 
box.show()

# %% [markdown]
# # How Much Can You Charge? Examine Paid App Pricing Strategies by Category
#
# **Challenge**: What is the median price price for a paid app? Then compare pricing by category by creating another box plot. But this time examine the prices (instead of the revenue estimates) of the paid apps. I recommend using `{categoryorder':'max descending'}` to sort the categories.

# %%
box = px.box(df_paid_apps,
             x='Category',
             y="Price",
             title='Price per Category')
 
box.update_layout(xaxis_title='Category',
                  yaxis_title='Paid App Price',
                  xaxis={'categoryorder':'max descending'},
                  yaxis=dict(type='log'))
 
box.show()
